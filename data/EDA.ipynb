# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('heart_dataset.csv')

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1323   57    0   0       140   241    0        1      123      1      0.2
# 1324   45    1   3       110   264    0        1      132      0      1.2
# 1325   68    1   0       144   193    1        1      141      0      3.4
# 1326   57    1   0       130   131    0        1      115      1      1.2
# 1327   57    0   1       130   236    0        0      174      0      0.0
#
#       slope  ca  thal  output
# 0         2   2     3       0
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'output'],
#       dtype='object')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  output
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1323   57    0   0       140   241    0        1      123      1      0.2
# 1324   45    1   3       110   264    0        1      132      0      1.2
# 1325   68    1   0       144   193    1        1      141      0      3.4
# 1326   57    1   0       130   131    0        1      115      1      1.2
# 1327   57    0   1       130   236    0        0      174      0      0.0
#
#       slope  ca  thal  output
# 1323      1   0     3       0
# 1324      1   0     3       0
# 1325      1   2     3       0
# 1326      1   1     3       0
# 1327      1   1     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1328 entries, 0 to 1327
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1328 non-null   int64
#  1   sex       1328 non-null   int64
#  2   cp        1328 non-null   int64
#  3   trestbps  1328 non-null   int64
#  4   chol      1328 non-null   int64
#  5   fbs       1328 non-null   int64
#  6   restecg   1328 non-null   int64
#  7   thalach   1328 non-null   int64
#  8   exang     1328 non-null   int64
#  9   oldpeak   1328 non-null   float64
#  10  slope     1328 non-null   int64
#  11  ca        1328 non-null   int64
#  12  thal      1328 non-null   int64
#  13  output    1328 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 145.4 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  1328.000000  1328.000000  1328.000000  1328.000000  1328.000000
# mean     54.418675     0.692771     0.948042   131.614458   246.060241
# std       9.071150     0.461519     1.029854    17.514997    51.627522
# min      29.000000     0.000000     0.000000    94.000000   126.000000
# 25%      48.000000     0.000000     0.000000   120.000000   211.000000
# 50%      56.000000     1.000000     1.000000   130.000000   240.000000
# 75%      61.000000     1.000000     2.000000   140.000000   275.000000
# max      77.000000     1.000000     3.000000   200.000000   564.000000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1328.000000  1328.000000  1328.000000  1328.000000  1328.000000
# mean      0.149096     0.529367   149.235693     0.334337     1.064232
# std       0.356318     0.527220    22.975286     0.471936     1.171519
# ...

# %%
df.isnull().sum()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# output      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_columns = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
for col in numerical_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'Distribution of {col}')
    plt.show()

categorical_columns = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'output']
for col in categorical_columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col)
    plt.title(f'Count Plot of {col}')
    plt.show()

# %%
numerical_columns = ['age', 'chol', 'trestbps', 'thalach', 'oldpeak']
categorical_columns = ['sex', 'cp', 'fbs', 'restecg', 'slope', 'ca', 'thal']

# %%
for col in categorical_columns:
    print(f"\nUnique values in {col}:")
    print(df[col].value_counts())
# Out:
# Unique values in sex:
# sex
# 1    920
# 0    408
# Name: count, dtype: int64
#
# Unique values in cp:
# cp
# 0    640
# 2    371
# 1    217
# 3    100
# Name: count, dtype: int64
#
# Unique values in fbs:
# fbs
# 0    1130
# 1     198
# Name: count, dtype: int64
#
# Unique values in restecg:
# restecg
# 1    665
# 0    644
# 2     19
# Name: count, dtype: int64
#
# Unique values in slope:
# slope
# 1    622
# 2    611
# 0     95
# Name: count, dtype: int64
#
# Unique values in ca:
# ca
# 0    753
# 1    291
# 2    172
# 3     89
# 4     23
# Name: count, dtype: int64
#
# Unique values in thal:
# thal
# 2    710
# 3    527
# 1     82
# 0      9
# Name: count, dtype: int64

# %%
from scipy.stats import skew, kurtosis
for col in numerical_columns:
    print(f"\nSkewness of {col}: {skew(df[col].dropna()):.2f}")
    print(f"Kurtosis of {col}: {kurtosis(df[col].dropna()):.2f}")
# Out:
# Skewness of age: -0.24
# Kurtosis of age: -0.53
#
# Skewness of chol: 1.09
# Kurtosis of chol: 4.07
#
# Skewness of trestbps: 0.73
# Kurtosis of trestbps: 0.96
#
# Skewness of thalach: -0.52
# Kurtosis of thalach: -0.09
#
# Skewness of oldpeak: 1.22
# Kurtosis of oldpeak: 1.35

# %% [markdown]
# Age:
# Skewness (-0.24): Slightly negatively skewed, indicating a small tail towards younger ages but generally symmetric.
# Kurtosis (-0.53): Platykurtic distribution, meaning it has lighter tails and a flatter peak compared to a normal distribution.
#
# Cholesterol (chol):
# Skewness (1.09): Positively skewed, suggesting a longer tail towards higher cholesterol levels.
# Kurtosis (4.07): Leptokurtic distribution, meaning it has heavier tails and a sharper peak than a normal distribution, indicating outliers or extreme values.
#
# Resting Blood Pressure (trestbps):
# Skewness (0.73): Moderately positively skewed, indicating higher values have a longer tail.
# Kurtosis (0.96): Slightly leptokurtic, suggesting mild outliers but relatively normal distribution.
#
# Maximum Heart Rate Achieved (thalach):
# Skewness (-0.52): Slightly negatively skewed, showing a small tail towards higher heart rate values.
# Kurtosis (-0.09): Mesokurtic or close to normal distribution, suggesting typical variability without extreme outliers.
#
# ST Depression (oldpeak):
# Skewness (1.22): Positively skewed, indicating a significant tail towards higher ST depression values.
# Kurtosis (1.35): Leptokurtic, suggesting the presence of significant outliers or extreme values in the dataset.
#
# Summary:
# The variables chol and oldpeak exhibit strong positive skewness and high kurtosis, which indicate potential outliers that should be examined further.
# Age and thalach are relatively symmetric and close to normal distributions, making them less problematic for analysis.
# Trestbps shows moderate skewness, requiring potential transformation if strict normality is needed for modeling.

# %%
for col in numerical_columns:
    plt.figure()
    sns.boxplot(x=df[col], palette='Set3')
    plt.title(f'Outliers in {col}')
    plt.xlabel(col)
    plt.show()

# %%
for col in categorical_columns:
    cross_tab = pd.crosstab(df[col], df['output'])
    cross_tab.div(cross_tab.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(8, 6), colormap='viridis')
    plt.title(f'Stacked Bar Chart of {col} by output')
    plt.xlabel(col)
    plt.ylabel('Proportion')
    plt.show()

# %%
correlations = df.corr()['output'].sort_values(ascending=False)
print(f"\nCorrelations with output:\n")
print(correlations)
# Out:
# Correlations with output:
#
# output      1.000000
# cp          0.434704
# thalach     0.422724
# slope       0.345709
# restecg     0.135011
# fbs        -0.038194
# chol       -0.096515
# trestbps   -0.140117
# age        -0.228442
# sex        -0.280008
# thal       -0.339286
# ca         -0.384375
# oldpeak    -0.436815
# exang      -0.437802
# Name: output, dtype: float64

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(df[numerical_columns + ['output']], hue='output', palette='coolwarm')
plt.title('Pairwise Relationships')
plt.show()

# %%
# Target Variable: The target variable output is fairly balanced, making it suitable for classification.

# Numerical Variables:
#     Key Variables: Higher heart rate (thalach) and lower ST depression (oldpeak) are linked to heart disease.
#     Outliers: Found in chol, trestbps, and oldpeak. These may need handling during preprocessing.
#     Skewness: Some variables, like chol and oldpeak, are skewed and might need transformation.

# Categorical Variables:
#     Notable Variables: Chest pain type (cp) and slope of peak exercise (slope) are strong indicators of heart disease.
#     Males appear more often in the dataset but are less likely to have heart disease.

# Correlations: thalach (positive) and oldpeak (negative) show the strongest correlations with the target variable.

# Key Insights: 
#     Patients with higher heart rates and lower ST depression levels are more likely to have heart disease.
#     Chest pain type and exercise slope provide important classification signals.
